# %%
# Set up and import dependencies
import pandas as pd
from sqlalchemy import create_engine
import re

import warnings
warnings.filterwarnings("ignore")

# %%
# Read input csv datafile
uni_2019 = pd.read_csv("Resources/QS World University Rankings 2019.csv")
uni_2019.head()
# Out:
#    year rank_display                                    university  score  \
# 0  2019            1  Massachusetts Institute of Technology (MIT)   100.0
# 1  2019            2                           Stanford University   98.6
# 2  2019            3                            Harvard University   98.5
# 3  2019            4  California Institute of Technology (Caltech)   97.2
# 4  2019            5                          University of Oxford   96.8
#
#                                                 link         country  \
# 0  https://www.topuniversities.com/universities/m...   United States
# 1  https://www.topuniversities.com/universities/s...   United States
# 2  https://www.topuniversities.com/universities/h...   United States
# 3  https://www.topuniversities.com/universities/c...   United States
# 4  https://www.topuniversities.com/universities/u...  United Kingdom
#
#         city         region                                               logo
# 0  Cambridge  North America  https://www.topuniversities.com/sites/default/...
# 1   Stanford  North America  https://www.topuniversities.com/sites/default/...
# 2  Cambridge  North America  https://www.topuniversities.com/sites/default/...
# 3   Pasadena  North America  https://www.topuniversities.com/sites/default/...
# 4     Oxford         Europe  https://www.topuniversities.com/sites/default/...

# %%
# Create pandas dataframe to hold the csv data
uni_rank_2019 = []
uni_rank_2019 = uni_2019[["year", "rank_display","university","score","country","city","region","link"]].copy()

# %%
# Analyse dataframe

uni_rank_2019.reset_index(drop=True,inplace=True)
uni_rank_2019
# Out:
#       year rank_display                                    university  score  \
# 0     2019            1  Massachusetts Institute of Technology (MIT)   100.0
# 1     2019            2                           Stanford University   98.6
# 2     2019            3                            Harvard University   98.5
# 3     2019            4  California Institute of Technology (Caltech)   97.2
# 4     2019            5                          University of Oxford   96.8
# ...    ...          ...                                           ...    ...
# 1013  2019        1000+  Université de Technologie de Compiègne (UTC)    NaN
# 1014  2019        1000+       University of California, San Francisco    NaN
# 1015  2019        1000+   Prague University of Economics and Business    NaN
# 1016  2019        1000+                 Weizmann Institute of Science    NaN
# 1017  2019        1000+     WHU - Otto Beisheim School of Management     NaN
#
#              country           city         region  \
# 0      United States      Cambridge  North America
# 1      United States       Stanford  North America
# 2      United States      Cambridge  North America
# 3      United States       Pasadena  North America
# 4     United Kingdom         Oxford         Europe
# ...              ...            ...            ...
# 1013          France      Compiègne         Europe
# 1014   United States  San Francisco  North America
# 1015  Czech Republic         Prague         Europe
# 1016          Israel        Rehovot           Asia
# 1017         Germany      Vallendar         Europe
#
#                                                    link
# 0     https://www.topuniversities.com/universities/m...
# 1     https://www.topuniversities.com/universities/s...
# 2     https://www.topuniversities.com/universities/h...
# 3     https://www.topuniversities.com/universities/c...
# 4     https://www.topuniversities.com/universities/u...
# ...                                                 ...
# 1013  https://www.topuniversities.com/universities/u...
# 1014  https://www.topuniversities.com/universities/u...
# 1015  https://www.topuniversities.com/universities/p...
# 1016  https://www.topuniversities.com/universities/w...
# 1017  https://www.topuniversities.com/universities/w...
#
# [1018 rows x 8 columns]

# %%
# Check for duplicated data
uni_rank_2019.duplicated().sum()
# Out:
# 0

# %%
# Check for a NaN in the entire dataframe
uni_rank_2019.isnull().values.any()
# Out:
# True

# %%
# Locate and count the NaNs in the dataframe columns
uni_rank_2019.isnull().sum()
# Out:
# year              0
# rank_display      0
# university        0
# score           515
# country           0
# city             25
# region            0
# link              0
# dtype: int64

# %%
# Get information of all columns in the dataframe
uni_rank_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1018 entries, 0 to 1017
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   year          1018 non-null   int64
#  1   rank_display  1018 non-null   object
#  2   university    1018 non-null   object
#  3   score         503 non-null    float64
#  4   country       1018 non-null   object
#  5   city          993 non-null    object
#  6   region        1018 non-null   object
#  7   link          1018 non-null   object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 63.8+ KB

# %%
# Transform data (cleanse) - Column: City

# Locate the position of the string that may contain city name in the university link
len("https://www.topuniversities.com/universities/")
# Out:
# 45

# %%
# Extract the string that contains 'city name' from the url and add to the dataframe as a new column
uni_rank_2019["city_extract"] = uni_rank_2019['link'].str[45:]
uni_rank_2019
# Out:
#       year rank_display                                    university  score  \
# 0     2019            1  Massachusetts Institute of Technology (MIT)   100.0
# 1     2019            2                           Stanford University   98.6
# 2     2019            3                            Harvard University   98.5
# 3     2019            4  California Institute of Technology (Caltech)   97.2
# 4     2019            5                          University of Oxford   96.8
# ...    ...          ...                                           ...    ...
# 1013  2019        1000+  Université de Technologie de Compiègne (UTC)    NaN
# 1014  2019        1000+       University of California, San Francisco    NaN
# 1015  2019        1000+   Prague University of Economics and Business    NaN
# 1016  2019        1000+                 Weizmann Institute of Science    NaN
# 1017  2019        1000+     WHU - Otto Beisheim School of Management     NaN
#
#              country           city         region  \
# 0      United States      Cambridge  North America
# 1      United States       Stanford  North America
# 2      United States      Cambridge  North America
# 3      United States       Pasadena  North America
# 4     United Kingdom         Oxford         Europe
# ...              ...            ...            ...
# 1013          France      Compiègne         Europe
# 1014   United States  San Francisco  North America
# 1015  Czech Republic         Prague         Europe
# 1016          Israel        Rehovot           Asia
# 1017         Germany      Vallendar         Europe
#
#                                                    link  \
# 0     https://www.topuniversities.com/universities/m...
# 1     https://www.topuniversities.com/universities/s...
# 2     https://www.topuniversities.com/universities/h...
# 3     https://www.topuniversities.com/universities/c...
# 4     https://www.topuniversities.com/universities/u...
# ...                                                 ...
# 1013  https://www.topuniversities.com/universities/u...
# 1014  https://www.topuniversities.com/universities/u...
# 1015  https://www.topuniversities.com/universities/p...
# 1016  https://www.topuniversities.com/universities/w...
# 1017  https://www.topuniversities.com/universities/w...
#
#                                     city_extract
# 0         massachusetts-institute-technology-mit
# 1                            stanford-university
# 2                             harvard-university
# 3        california-institute-technology-caltech
# 4                              university-oxford
# ...                                          ...
# 1013  universite-de-technologie-de-compiegne-utc
# 1014         university-california-san-francisco
# 1015        prague-university-economics-business
# 1016                  weizmann-institute-science
# 1017         whu-otto-beisheim-school-management
#
# [1018 rows x 9 columns]

# %%
# Drop the unwanted link column
uni_rank_2019 = uni_rank_2019.drop(["link"], axis=1)

# Locate the NaN value in the city column
uni_rank_2019[uni_rank_2019["city"].isnull()]
# Out:
#       year rank_display                                      university  \
# 49    2019           50                                  Université PSL
# 74    2019           75                             Sorbonne University
# 140   2019          141                               Aarhus University
# 179   2019          180                      Queen's University Belfast
# 240   2019          239                         Université Paris-Saclay
# 264   2019          264                            Kyung Hee University
# 331   2019          332                        Brunel University London
# 363   2019          363                       Oxford Brookes University
# 372   2019          373  National Research Tomsk Polytechnic University
# 434   2019          435                               Bangor University
# 444   2019          443                             University of Macau
# 481   2019          481                                 UCSI University
# 499   2019          500                 Singapore Management University
# 539   2019      531-540               University Paris 2 Panthéon-Assas
# 678   2019      651-700                      Palacký University Olomouc
# 686   2019      651-700                             Université de Lille
# 741   2019      701-750                         University of Greenwich
# 761   2019      751-800                     German Jordanian University
# 762   2019      751-800                            Jamia Millia Islamia
# 772   2019      751-800            Lviv Polytechnic National University
# 794   2019      751-800                          University of Brighton
# 831   2019     801-1000                        Central South University
# 875   2019     801-1000                 Poznań University of Technology
# 934   2019     801-1000                            Universidade de Vigo
# 1011  2019        1000+                   Stockholm School of Economics
#
#       score           country city  region  \
# 49     75.1            France  NaN  Europe
# 74     64.8            France  NaN  Europe
# 140    50.7           Denmark  NaN  Europe
# 179    45.9    United Kingdom  NaN  Europe
# 240    38.9            France  NaN  Europe
# 264    36.7       South Korea  NaN    Asia
# 331    32.0    United Kingdom  NaN  Europe
# 363    30.1    United Kingdom  NaN  Europe
# 372    29.4            Russia  NaN  Europe
# 434    26.4    United Kingdom  NaN  Europe
# 444    26.0         Macau SAR  NaN    Asia
# 481    24.4          Malaysia  NaN    Asia
# 499    23.5         Singapore  NaN    Asia
# 539     NaN            France  NaN  Europe
# 678     NaN    Czech Republic  NaN  Europe
# 686     NaN            France  NaN  Europe
# 741     NaN    United Kingdom  NaN  Europe
# 761     NaN            Jordan  NaN    Asia
# 762     NaN             India  NaN    Asia
# 772     NaN           Ukraine  NaN  Europe
# 794     NaN    United Kingdom  NaN  Europe
# 831     NaN  China (Mainland)  NaN    Asia
# 875     NaN            Poland  NaN  Europe
# 934     NaN             Spain  NaN  Europe
# 1011    NaN            Sweden  NaN  Europe
#
#                                         city_extract
# 49                                    universite-psl
# 74                               sorbonne-university
# 140                                aarhus-university
# 179                        queens-university-belfast
# 240                          universite-paris-saclay
# 264                             kyung-hee-university
# 331                         brunel-university-london
# 363                        oxford-brookes-university
# 372   national-research-tomsk-polytechnic-university
# 434                                bangor-university
# 444                                 university-macau
# 481                                  ucsi-university
# 499                  singapore-management-university
# 539                university-paris-2-pantheon-assas
# 678                       palacky-university-olomouc
# 686                              universite-de-lille
# 741                             university-greenwich
# 761                      german-jordanian-university
# 762                             jamia-millia-islamia
# 772             lviv-polytechnic-national-university
# 794                              university-brighton
# 831                         central-south-university
# 875                     poznan-university-technology
# 934                             universidade-de-vigo
# 1011                      stockholm-school-economics

# %%
# Count the NaN value in the city column
uni_rank_2019["city"].isnull().sum()
# Out:
# 25

# %%
# Initialise a new list and copy over the data for the cleansing process
df = []
df = uni_rank_2019.copy()

# %%
# Split the city_extract column into multiple columns to get the city name
df["city_e1"] = df["city_extract"].str.split('-').str[0]
df["city_e2"] = df["city_extract"].str.split('-').str[1]
df["city_e3"] = df["city_extract"].str.split('-').str[2]
df["city_e4"] = df["city_extract"].str.split('-').str[3]
df["city_e5"] = df["city_extract"].str.split('-').str[4]
df["city_e6"] = df["city_extract"].str.split('-').str[5]
df[df["city"].isnull()]
# Out:
#       year rank_display                                      university  \
# 49    2019           50                                  Université PSL
# 74    2019           75                             Sorbonne University
# 140   2019          141                               Aarhus University
# 179   2019          180                      Queen's University Belfast
# 240   2019          239                         Université Paris-Saclay
# 264   2019          264                            Kyung Hee University
# 331   2019          332                        Brunel University London
# 363   2019          363                       Oxford Brookes University
# 372   2019          373  National Research Tomsk Polytechnic University
# 434   2019          435                               Bangor University
# 444   2019          443                             University of Macau
# 481   2019          481                                 UCSI University
# 499   2019          500                 Singapore Management University
# 539   2019      531-540               University Paris 2 Panthéon-Assas
# 678   2019      651-700                      Palacký University Olomouc
# 686   2019      651-700                             Université de Lille
# 741   2019      701-750                         University of Greenwich
# 761   2019      751-800                     German Jordanian University
# 762   2019      751-800                            Jamia Millia Islamia
# 772   2019      751-800            Lviv Polytechnic National University
# 794   2019      751-800                          University of Brighton
# 831   2019     801-1000                        Central South University
# 875   2019     801-1000                 Poznań University of Technology
# 934   2019     801-1000                            Universidade de Vigo
# 1011  2019        1000+                   Stockholm School of Economics
#
#       score           country city  region  \
# 49     75.1            France  NaN  Europe
# 74     64.8            France  NaN  Europe
# 140    50.7           Denmark  NaN  Europe
# 179    45.9    United Kingdom  NaN  Europe
# 240    38.9            France  NaN  Europe
# 264    36.7       South Korea  NaN    Asia
# 331    32.0    United Kingdom  NaN  Europe
# 363    30.1    United Kingdom  NaN  Europe
# 372    29.4            Russia  NaN  Europe
# 434    26.4    United Kingdom  NaN  Europe
# 444    26.0         Macau SAR  NaN    Asia
# 481    24.4          Malaysia  NaN    Asia
# 499    23.5         Singapore  NaN    Asia
# 539     NaN            France  NaN  Europe
# 678     NaN    Czech Republic  NaN  Europe
# 686     NaN            France  NaN  Europe
# 741     NaN    United Kingdom  NaN  Europe
# 761     NaN            Jordan  NaN    Asia
# 762     NaN             India  NaN    Asia
# 772     NaN           Ukraine  NaN  Europe
# 794     NaN    United Kingdom  NaN  Europe
# 831     NaN  China (Mainland)  NaN    Asia
# 875     NaN            Poland  NaN  Europe
# 934     NaN             Spain  NaN  Europe
# 1011    NaN            Sweden  NaN  Europe
#
#                                         city_extract       city_e1  \
# 49                                    universite-psl    universite
# 74                               sorbonne-university      sorbonne
# 140                                aarhus-university        aarhus
# 179                        queens-university-belfast        queens
# 240                          universite-paris-saclay    universite
# 264                             kyung-hee-university         kyung
# 331                         brunel-university-london        brunel
# 363                        oxford-brookes-university        oxford
# 372   national-research-tomsk-polytechnic-university      national
# 434                                bangor-university        bangor
# 444                                 university-macau    university
# 481                                  ucsi-university          ucsi
# 499                  singapore-management-university     singapore
# 539                university-paris-2-pantheon-assas    university
# 678                       palacky-university-olomouc       palacky
# 686                              universite-de-lille    universite
# 741                             university-greenwich    university
# 761                      german-jordanian-university        german
# 762                             jamia-millia-islamia         jamia
# 772             lviv-polytechnic-national-university          lviv
# 794                              university-brighton    university
# 831                         central-south-university       central
# 875                     poznan-university-technology        poznan
# 934                             universidade-de-vigo  universidade
# 1011                      stockholm-school-economics     stockholm
#
#           city_e2     city_e3      city_e4     city_e5 city_e6
# 49            psl         NaN          NaN         NaN     NaN
# 74     university         NaN          NaN         NaN     NaN
# 140    university         NaN          NaN         NaN     NaN
# 179    university     belfast          NaN         NaN     NaN
# 240         paris      saclay          NaN         NaN     NaN
# 264           hee  university          NaN         NaN     NaN
# 331    university      london          NaN         NaN     NaN
# 363       brookes  university          NaN         NaN     NaN
# 372      research       tomsk  polytechnic  university     NaN
# 434    university         NaN          NaN         NaN     NaN
# 444         macau         NaN          NaN         NaN     NaN
# 481    university         NaN          NaN         NaN     NaN
# 499    management  university          NaN         NaN     NaN
# 539         paris           2     pantheon       assas     NaN
# 678    university     olomouc          NaN         NaN     NaN
# 686            de       lille          NaN         NaN     NaN
# 741     greenwich         NaN          NaN         NaN     NaN
# 761     jordanian  university          NaN         NaN     NaN
# 762        millia     islamia          NaN         NaN     NaN
# 772   polytechnic    national   university         NaN     NaN
# 794      brighton         NaN          NaN         NaN     NaN
# 831         south  university          NaN         NaN     NaN
# 875    university  technology          NaN         NaN     NaN
# 934            de        vigo          NaN         NaN     NaN
# 1011       school   economics          NaN         NaN     NaN

# %%
# Update the city column with the name extracted from the university URL
df.iloc[[49],[5]] = "Paris"
df.iloc[[74],[5]] = "Paris"
df.iloc[[140],[5]] = "Aarhus"
df.iloc[[179],[5]] = "Belfast"
df.iloc[[240],[5]] = "Paris"
df.iloc[[264],[5]] = "Kyung Hee"
df.iloc[[331],[5]] = "London"
df.iloc[[363],[5]] = "Oxford"
df.iloc[[372],[5]] = "Tomsk"
df.iloc[[434],[5]] = "Bangor"
df.iloc[[444],[5]] = "Macau"
df.iloc[[481],[5]] = "Kuala Lumpur"
df.iloc[[499],[5]] = "Singapore"
df.iloc[[539],[5]] = "Paris"
df.iloc[[678],[5]] = "Olomouc"
df.iloc[[686],[5]] = "Lille"
df.iloc[[741],[5]] = "Greenwich"
df.iloc[[761],[5]] = "Madaba"
df.iloc[[762],[5]] = "New Delhi"
df.iloc[[772],[5]] = "Lviv"
df.iloc[[794],[5]] = "Brighton"
df.iloc[[831],[5]] = "Changsha"
df.iloc[[875],[5]] = "Poznan"
df.iloc[[934],[5]] = "Vigo"
df.iloc[[1011],[5]] = "Stockholm"

# %%
# Check whether there is any NaN in the city column
df.loc[(df["city"].isnull())]
# Out:
# Empty DataFrame
# Columns: [year, rank_display, university, score, country, city, region, city_extract, city_e1, city_e2, city_e3, city_e4, city_e5, city_e6]
# Index: []

# %%
# Drop the unused columns
df = df.drop(["city_e1","city_e2","city_e3","city_e4","city_e5","city_e6","city_extract"], axis=1)
df.head()
# Out:
#    year rank_display                                    university  score  \
# 0  2019            1  Massachusetts Institute of Technology (MIT)   100.0
# 1  2019            2                           Stanford University   98.6
# 2  2019            3                            Harvard University   98.5
# 3  2019            4  California Institute of Technology (Caltech)   97.2
# 4  2019            5                          University of Oxford   96.8
#
#           country       city         region
# 0   United States  Cambridge  North America
# 1   United States   Stanford  North America
# 2   United States  Cambridge  North America
# 3   United States   Pasadena  North America
# 4  United Kingdom     Oxford         Europe

# %%
# Transform data (cleanse) - Column: Rank_Display & Score

# Split the unwanted characters, capture the ranking from the column rank_display and store the data in the new column
df["rank"] = df['rank_display'].str.split('-').str[0]
df["rank"] = df['rank_display'].str.split('+').str[0]
df.tail(10)
# Out:
#       year rank_display                                         university  \
# 1008  2019        1000+                              Karolinska Institutet
# 1009  2019        1000+  King Abdullah University of Science & Technolo...
# 1010  2019        1000+                             London Business School
# 1011  2019        1000+                      Stockholm School of Economics
# 1012  2019        1000+                                 Bocconi University
# 1013  2019        1000+       Université de Technologie de Compiègne (UTC)
# 1014  2019        1000+            University of California, San Francisco
# 1015  2019        1000+        Prague University of Economics and Business
# 1016  2019        1000+                      Weizmann Institute of Science
# 1017  2019        1000+          WHU - Otto Beisheim School of Management
#
#       score         country           city         region  rank
# 1008    NaN          Sweden      Stockholm         Europe  1000
# 1009    NaN    Saudi Arabia         Thuwal           Asia  1000
# 1010    NaN  United Kingdom         London         Europe  1000
# 1011    NaN          Sweden      Stockholm         Europe  1000
# 1012    NaN           Italy          Milan         Europe  1000
# 1013    NaN          France      Compiègne         Europe  1000
# 1014    NaN   United States  San Francisco  North America  1000
# 1015    NaN  Czech Republic         Prague         Europe  1000
# 1016    NaN          Israel        Rehovot           Asia  1000
# 1017    NaN         Germany      Vallendar         Europe  1000

# %%
# Check whether the column rank contains any unwanted characters
df[df["rank"].str.match('^=.*')==True]
# Out:
# Empty DataFrame
# Columns: [year, rank_display, university, score, country, city, region, rank]
# Index: []

# %%
# Remove all the unwanted characters
df["rank"].replace("=",'',regex=True, inplace=True)
df["rank"] = df['rank'].str.split('-').str[0]

# Check whether all the unwanted characters had been removed
df[df["rank"].str.match('^=.*')==True]
# Out:
# Empty DataFrame
# Columns: [year, rank_display, university, score, country, city, region, rank]
# Index: []

# %%
# Fill all NaN values with 0 (zero)
df["score"] =  df["score"].fillna(0)
df["rank_display"] = df["rank_display"].fillna(0)
df["rank"] = df["rank"].fillna(0)

# Check to see whether there is any NaN value left in the dataframe
df.isnull().sum()
# Out:
# year            0
# rank_display    0
# university      0
# score           0
# country         0
# city            0
# region          0
# rank            0
# dtype: int64

# %%
# Convert the column rank to integer
df["rank"] = pd.to_numeric(df["rank"])

# %%
# Set index column as table "id" column
df.reset_index(drop=True,inplace=True)
df['id'] = df.index
df.set_index("id")
# Out:
#       year rank_display                                    university  score  \
# id
# 0     2019            1  Massachusetts Institute of Technology (MIT)   100.0
# 1     2019            2                           Stanford University   98.6
# 2     2019            3                            Harvard University   98.5
# 3     2019            4  California Institute of Technology (Caltech)   97.2
# 4     2019            5                          University of Oxford   96.8
# ...    ...          ...                                           ...    ...
# 1013  2019        1000+  Université de Technologie de Compiègne (UTC)    0.0
# 1014  2019        1000+       University of California, San Francisco    0.0
# 1015  2019        1000+   Prague University of Economics and Business    0.0
# 1016  2019        1000+                 Weizmann Institute of Science    0.0
# 1017  2019        1000+     WHU - Otto Beisheim School of Management     0.0
#
#              country           city         region  rank
# id
# 0      United States      Cambridge  North America     1
# 1      United States       Stanford  North America     2
# 2      United States      Cambridge  North America     3
# 3      United States       Pasadena  North America     4
# 4     United Kingdom         Oxford         Europe     5
# ...              ...            ...            ...   ...
# 1013          France      Compiègne         Europe  1000
# 1014   United States  San Francisco  North America  1000
# 1015  Czech Republic         Prague         Europe  1000
# 1016          Israel        Rehovot           Asia  1000
# 1017         Germany      Vallendar         Europe  1000
#
# [1018 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1018 entries, 0 to 1017
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   year          1018 non-null   int64
#  1   rank_display  1018 non-null   object
#  2   university    1018 non-null   object
#  3   score         1018 non-null   float64
#  4   country       1018 non-null   object
#  5   city          1018 non-null   object
#  6   region        1018 non-null   object
#  7   rank          1018 non-null   int64
#  8   id            1018 non-null   int64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 71.7+ KB

# %%
# Transform data - Finalise DataFrames

uni_rank_transformed = []
uni_rank_transformed = df[["id","year","rank","score"]].copy()
uni_rank_transformed.set_index("id",drop=True, inplace=True)
uni_rank_transformed.head()
# Out:
#     year  rank  score
# id
# 0   2019     1  100.0
# 1   2019     2   98.6
# 2   2019     3   98.5
# 3   2019     4   97.2
# 4   2019     5   96.8

# %%
uni_details_transformed = []
uni_details_transformed = df[["id","university","city","country","region"]].copy()
uni_details_transformed.set_index("id",drop=True, inplace=True)
uni_details_transformed.head()
# Out:
#                                       university       city         country  \
# id
# 0   Massachusetts Institute of Technology (MIT)   Cambridge   United States
# 1                            Stanford University   Stanford   United States
# 2                             Harvard University  Cambridge   United States
# 3   California Institute of Technology (Caltech)   Pasadena   United States
# 4                           University of Oxford     Oxford  United Kingdom
#
#            region
# id
# 0   North America
# 1   North America
# 2   North America
# 3   North America
# 4          Europe

# %%
# Create postgresql database connection

connection_string = "postgres:<pass wd>@localhost:5432/QS_Uni_Ranking_2019"
engine = create_engine(f'postgresql://{connection_string}')

# %%
# Confirm tables creation in pgAdmin4
engine.table_names()
# Out:
# ['uni_rank', 'uni_details']

# %%
# Load pandas DataFrames into database

uni_rank_transformed.to_sql(name='uni_rank', con=engine, if_exists='append', index=True)

# %%
uni_details_transformed.to_sql(name='uni_details', con=engine, if_exists='append', index=True)
